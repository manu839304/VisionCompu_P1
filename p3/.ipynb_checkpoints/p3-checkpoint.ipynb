# %% [markdown]
# ## Image classification with deep learning methods.
#
# --- Description ---
#
# When you train the network, it is recommended to use the GPU resources of your computer.
# This will help you to learn the "know how" of setting up a working Python environment on your computer.
# In the case of unavailable Nvidia hardware or problems with your Python environment you can use Google Colab.
# Please go to the menu, Runtime - Change runtime type, and select **GPU** as the hardware accelerator.
# Although you used your computer successfuly it is highly recommended to give a try to Google Colab environment.

# %%
# Import libraries
# These libraries should be sufficient for this Practice.
# However, if any other library is needed, please install it by yourself.
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
import numpy as np
import time
import os
import random
import matplotlib.pyplot as plt
from matplotlib import colors
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import roc_auc_score

# %%
# Install and import the MedMNIST package and datasets.

# !pip install medmnist
import medmnist
from medmnist import info
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (1.26.4)
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (1.6.1)
# Collecting scikit-image (from medmnist)
#   Downloading scikit_image-0.25.2-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: tqdm in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (4.67.1)
# Requirement already satisfied: Pillow in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (11.1.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (2.6.0)
# Requirement already satisfied: torchvision in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from medmnist) (0.21.0)
# Collecting termcolor (from fire->medmnist)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from pandas->medmnist) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from pandas->medmnist) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from pandas->medmnist) (2023.3)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from scikit-image->medmnist) (1.15.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from scikit-image->medmnist) (3.4.2)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->medmnist)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->medmnist)
#   Downloading tifffile-2025.3.13-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from scikit-image->medmnist) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image->medmnist)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from scikit-learn->medmnist) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from scikit-learn->medmnist) (3.5.0)
# Requirement already satisfied: filelock in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from torch->medmnist) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from torch->medmnist) (4.12.2)
# Requirement already satisfied: jinja2 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from torch->medmnist) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from torch->medmnist) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from torch->medmnist) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from sympy==1.13.1->torch->medmnist) (1.3.0)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from tqdm->medmnist) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\anaconda3\envs\prac_apr\lib\site-packages (from jinja2->torch->medmnist) (2.1.3)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading scikit_image-0.25.2-cp310-cp310-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 840.2 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/12.8 MB 840.2 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.8 MB 958.5 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.8 MB 949.8 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.8 MB 949.8 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.8 MB 883.4 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.3/12.8 MB 883.4 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.6/12.8 MB 822.8 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.6/12.8 MB 822.8 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.8/12.8 MB 762.8 kB/s eta 0:00:15
#    ------ --------------------------------- 2.1/12.8 MB 798.9 kB/s eta 0:00:14
#    ------- -------------------------------- 2.4/12.8 MB 818.6 kB/s eta 0:00:13
#    -------- ------------------------------- 2.6/12.8 MB 820.6 kB/s eta 0:00:13
#    -------- ------------------------------- 2.6/12.8 MB 820.6 kB/s eta 0:00:13
#    --------- ------------------------------ 2.9/12.8 MB 830.6 kB/s eta 0:00:12
#    --------- ------------------------------ 3.1/12.8 MB 846.6 kB/s eta 0:00:12
#    ---------- ----------------------------- 3.4/12.8 MB 842.5 kB/s eta 0:00:12
#    ---------- ----------------------------- 3
/s eta 0:00:01
#    -------------------------------------- - 12.3/12.8 MB 940.0 kB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 946.7 kB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 947.2 kB/s eta 0:00:00
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2025.3.13-py3-none-any.whl (226 kB)
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114318 sha256=b4621e353b135356cc34e60294f317849541cd6c9eacaf6be8ad011e1c322538
#   Stored in directory: c:\users\usuario\appdata\local\pip\cache\wheels\19\39\2f\2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# Installing collected packages: tifffile, termcolor, lazy-loader, imageio, scikit-image, fire, medmnist
# Successfully installed fire-0.7.0 imageio-2.37.0 lazy-loader-0.4 medmnist-3.0.2 scikit-image-0.25.2 termcolor-2.5.0 tifffile-2025.3.13

# %% [markdown]
# ## Download the imaging dataset
#
# You can browse the imaging datasets on their webpage https://medmnist.com/, and download them as such:

# %%
from medmnist import OrganAMNIST

train_set = OrganAMNIST(split="train", download=True)
val_set = OrganAMNIST(split="val", download=True)
test_set = OrganAMNIST(split="test", download=True)
# Out:
# 100.0%

# %% [markdown]
# ## Visualize the imaging dataset
#
# You can find relevant information about the datasets in the info.INFO dictionary.
#
# For visualizing the images, you can use the montage method, though we recomend
# you practice accesing the individual images and labels.

# %%
train_set.montage(length=10)
# Out:
# <PIL.Image.Image image mode=L size=280x280>

# %%
image, label = train_set[0]
print("Tamaño de la imagen:", np.array(image).shape)
# Out:
# Tamaño de la imagen: (28, 28)

# %% [markdown]
# # Generate a dataloader
#
# A convinient option for accessing data in torch is with the use of the Dataloader class. These work directly when given a MNIST dataset as input.
# You can also apply any necesary preprocesing steps directly as you load the data with the Transforms package and the transform MNIST argument.
#
# Choose apropiate values for the training hiperparameters (you can experiment with sampling strategies if you want) and implement the adecuate preprocesing steps. Finally, choose an Mnist dataset and create the dataloader for the training, validation and test splits.

# %%
from medmnist import INFO, Evaluator

data_flag = 'organamnist'

NUM_EPOCHS = 3
BATCH_SIZE = 128
lr = 0.001

im_size = 28
in_channels = 784
num_classes = 11

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])

# Load and preprocess data
data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5])
])

train_dataset = DataClass(split='train', transform=data_transform, download=download)
test_dataset = DataClass(split='test', transform=data_transform, download=download)

# encapsulate data into dataloader form
train_loader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
test_loader = data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)

#Define loss function and optimizer
#Your code

# %% [markdown]
# #Create a deep learning model

# %%
# Define a simple CNN model

class Net(nn.Module):
    def __init__(self, in_channels, num_classes, im_size):
        super(Net, self).__init__()
        #Define the desired deep learning model
        #Your code

        #End your code

    def forward(self, x):
        #Your code

        #End your code

model = Net(in_channels=in_channels, num_classes=num_classes, im_size = im_size)

# %% [markdown]
# #Train Model
#
# Implement the main traning loop to train the deep learning model.
# This should include the forward and backward passes. You can find information about how to do this with torch in https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#id14

# %%
# Train the model

for epoch in range(NUM_EPOCHS):

    model.train()
    for inputs, targets in tqdm(train_loader):
        # forward + backward + optimize

        #Your code

# %% [markdown]
# #Evaluation
#
# Finally, implement the evaluation of the object clasification task. You can implement any metric you want, though the most common are accuracy and AUC (one class against all for the multiclass task). You can use torch.no_grad() for speeding up predictions when no gradients are needed.
#
# How do you compare with the MedMNIST benchmarks?

# %%
# Evaluation

# Your code
